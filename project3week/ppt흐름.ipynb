# %% [markdown]
# # 서론 2장
# 1page: 서울에 전세집구하는 것에 대한 어려움? 인사이트들? 자료 3개
#
# 2Page: 사용한 데이터set, 어떤 데이터였는지? 간략하게 사진?으로 칼럼이나 이상치? 이런것들 null값이나
# - point: 얼마나 더럽나 우리가 이제 이걸 어떻게 깨끗이 하나.
#
# # 본론 27장
# 3page: - 데이터 전처리: null값을 어떻게 처리했는지? 예를들어 전세보증금이면 전체에 평균을 낼 수 없다. 왜냐하면 불균형한 데이터이기 때문이다. 데이터자체의 성향이 불균형하다. 아파트가 거래량에서 압도적으로 많기 때문이다. 따라서 type별로 중앙값을 줬다~ 이런식으로
#
# 4Page: 경도 위도 구하기- 거리데이터를 구하기 위함. 경도 위도 구하는 솔루션에 대해서 설명.
# 어느정도는 첨부. 코드에 대한 설명도 제가 넣어드립니다.
# 1. 라이브러리 설명
# 2. 왜 사용하나? (공식- 하버사인 공식 지구에서 거리를 구하는 공식이다..)
# 3. 코드설명
#
# 5page: 경도 위도를 통해 거리데이터를 어떻게 사용: 사용하는데 저희는 범주라는 것을 사용하여 일정 범주안에 들어가는 집의 개수를 파악했다.
# 이거에 대해서도 제가 첨부합니다.
#
# 6page: 파편화된 데이터셋을 어떻게 하나의 데이터로 통합하였는가? crossjoin과 non-equi join
# - 경도위도와 주소, 혹은 개업일자나 폐업일자(있는경우만)만 남기고 나머지 데이터 칼럼은 Drop
# - 경도위도만 원본데이터셋에 붙였다.
# - 붙이는 과정을 클러스터링해서 하나의 시각화?
#
# 7page: EDA:
# 1. 기술적 통계 분석 원본 데이터셋을 train과 test로 나눔. 타겟도 나눔
# 2. 전체적Info
# 3. 범주형 info
# 4. 수치형 info
#
# 8Page: 타겟분석 시각화 변환까지 (최대한 한페이지 안되면 공유!)
# 1. 추론은 첨언
#
# 9page~10Page: 연속형 피처
# 11Page: 범주형,
# 12page: 불연속형 숫자형 피처
#
# 13page: 상관관계 분석, 가설제시 및 검증 시각화
#
# 14Page~15page 문화 외식 인프라가 최근방 아파트 전세값에 영향을?
# 16p~17p: 정권
# 18p~19p: 계절
# 20p~21p: top5 보증금 평균 추이
#
# 22p: 데이터 전처리 Part2
# 1. 타겟값 정규화
# 2. 연속형 피처 boxcos 왜곡도 줄임
#
# 23P: +코드 첨부
# 1. 범주형 타깃 인코딩
# 2. 피처 라벨 인코딩
# 3. 명목 범주형 원핫 인코딩
# 4. 레이블 분리
# 5. scale
#
# 24p
# 1. 머신러닝을 위한 데이터셋 나누기
# 2. EDA에 대한 첨언? 저희 조의 생각 머신러닝 방향
# 3. 목점함수와 모델링을 어떻게 할것인지에 대한 개괄
#
# 25p
# 1. 모델링 진행 일반선형모델과 결정트리모델 2가지 시연(베이스라인 -기초)
# 2. 점수비교 결정트리 선택
#
# 26p
# 1. 규제모델 만들어보기(결정트리 규제모델 부스팅, 배깅)
# 2. 부스팅 채택
# 3. XGBoost 사용선택
#
# 27P
# 1. XGBoost 점수확인 및 하이퍼파라미터 종류 보여주기? 확인
# 2. 하이퍼파라미터를 넣어서 돌려보자.
# - Gridsearch와 randomizedsearch사용해서 하이퍼파라미터 다루기
#
# 28P
# - 하이어파라미터 조정하는 전략 소개
#
# 29p
# - 앙상블 모델
#
# # 결론 1장
# 30p 결론
# - 최종점수와 유의미안 피처 고르기
# - 그 피처에 대해서 집중하여 전략 제시하기
# e.g) 집을 살 때는 면적이 높은 것을 구매하는 것을 당연히 고려해하고 유치원수가 많은지에 여부도 강남권에 집을 살 때 좋습니다.
# 강남권에 집을 구매한다면 성장폭이 높았던 어디 지역을 구매하고... 노후화된 아파트단지가 많은 어디동도 좋을 것 가탇.
# 스타벅스나 미슐랭같은 인프라데이터는 가격에 영향을 많이 미치지 않는 것을 확인했고 강남권에서는 다른지역도 알아볼 수 있는 여지?를 만들 수 있고 궁금해졌다.( 프로젝트에 확장성)
#
# 역세권도 강남권은 잘 갖춰있어서 집값에 유의미한 영향을 주지는 못했지만 낮은 가격대의 집에서는 고려할 수 있는 지표였다...
# .
# .
# .
# .
# .
