# %%
import pandas as pd
df1 = pd.read_csv('루트데이터위도경도')
# Out:
# /var/folders/yh/smj7ptzs057g14vbhqqqhcq00000gn/T/ipykernel_34696/1980413226.py:2: DtypeWarning: Columns (9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('루트데이터위도경도')

# %%
pip install geopy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
def calculate_distance(row):
    try:
        return geodesic((row['Latitude'], row['Longitude']), (row['역세권위도'], row['역세권경도'])).kilometers
    except (ValueError, TypeError):
        return None

df1['Distance_to_station'] = df1.apply(calculate_distance, axis=1)

df1
# Out:
#          Unnamed: 0            시군구 전월세구분  보증금(만원)  건축년도     구분  전용면적(㎡)     층  \
# 0                 0  서울특별시 강남구 개포동    전세     7500  1989  단독다가구    44.00   3.0
# 1                 1  서울특별시 강남구 개포동    전세     7500  1989  단독다가구    44.00   3.0
# 2                 2  서울특별시 강남구 개포동    전세     7500  1989  단독다가구    44.00   3.0
# 3                 3  서울특별시 강남구 개포동    전세     7500  1989  단독다가구    44.00   3.0
# 4                 4  서울특별시 강남구 개포동    전세     7500  1989  단독다가구    44.00   3.0
# ...             ...            ...   ...      ...   ...    ...      ...   ...
# 2358742     2358742  서울특별시 강남구 청담동    전세    80000  2019   오피스텔    45.09  17.0
# 2358743     2358743  서울특별시 강남구 청담동    전세    80000  2019   오피스텔    45.09  17.0
# 2358744     2358744  서울특별시 강남구 청담동    전세    80000  2019   오피스텔    45.09  17.0
# 2358745     2358745  서울특별시 강남구 청담동    전세    80000  2019   오피스텔    45.09  17.0
# 2358746     2358746  서울특별시 강남구 청담동    전세    80000  2019   오피스텔    45.09  17.0
#
# ...

# %%
df1['Distance_to_station'] = df1['Distance_to_station'].apply(lambda x: round(x, 2))

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2358747 entries, 0 to 2358746
# Data columns (total 19 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   Unnamed: 0           int64
#  1   시군구                  object
#  2   전월세구분                object
#  3   보증금(만원)              int64
#  4   건축년도                 int64
#  5   구분                   object
#  6   전용면적(㎡)              float64
#  7   층                    float64
#  8   도로명주소                object
#  9   계약시작                 object
#  10  계약종료                 object
#  11  계약년월일                object
#  12  구                    object
#  13  건축나이                 int64
#  14  Latitude             float64
#  15  Longitude            float64
#  16  역세권위도                float64
#  17  역세권경도                float64
#  18  Distance_to_station  float64
# dtypes: float64(7), int64(4), object(8)
# memory usage: 341.9+ MB
