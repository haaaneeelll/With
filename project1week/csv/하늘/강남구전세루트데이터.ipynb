# %%
import pandas as pd

# %%
df1 = pd.read_csv("강남구전세(3차전처리).csv")
df1
# Out:
#        Unnamed: 0            시군구 전월세구분  보증금(만원)  건축년도     구분  전용면적(㎡)     층  \
# 0               0  서울특별시 강남구 개포동    전세     7500  1989  단독다가구    44.00   3.0
# 1               1  서울특별시 강남구 개포동    전세    11000  1994  단독다가구    44.00   3.0
# 2               2  서울특별시 강남구 개포동    전세    16800  2000  단독다가구    44.00   3.0
# 3               3  서울특별시 강남구 개포동    전세    13000  1989  단독다가구    44.00   3.0
# 4               4  서울특별시 강남구 개포동    전세     8000  1995  단독다가구    44.00   3.0
# ...           ...            ...   ...      ...   ...    ...      ...   ...
# 87356       87356  서울특별시 강남구 청담동    전세    10000  2003   오피스텔    17.73   3.0
# 87357       87357  서울특별시 강남구 청담동    전세    10500  2003   오피스텔    17.73   1.0
# 87358       87358  서울특별시 강남구 청담동    전세    11000  2003   오피스텔    17.73   1.0
# 87359       87359  서울특별시 강남구 청담동    전세    13000  1991   오피스텔    22.77  11.0
# 87360       87360  서울특별시 강남구 청담동    전세    80000  2019   오피스텔    45.09  17.0
#
# ...

# %%
df1
# Out:
#        Unnamed: 0            시군구 전월세구분  보증금(만원)  건축년도     구분  전용면적(㎡)     층  \
# 0               0  서울특별시 강남구 개포동    전세     7500  1989  단독다가구    44.00   3.0
# 1               1  서울특별시 강남구 개포동    전세    11000  1994  단독다가구    44.00   3.0
# 2               2  서울특별시 강남구 개포동    전세    16800  2000  단독다가구    44.00   3.0
# 3               3  서울특별시 강남구 개포동    전세    13000  1989  단독다가구    44.00   3.0
# 4               4  서울특별시 강남구 개포동    전세     8000  1995  단독다가구    44.00   3.0
# ...           ...            ...   ...      ...   ...    ...      ...   ...
# 87356       87356  서울특별시 강남구 청담동    전세    10000  2003   오피스텔    17.73   3.0
# 87357       87357  서울특별시 강남구 청담동    전세    10500  2003   오피스텔    17.73   1.0
# 87358       87358  서울특별시 강남구 청담동    전세    11000  2003   오피스텔    17.73   1.0
# 87359       87359  서울특별시 강남구 청담동    전세    13000  1991   오피스텔    22.77  11.0
# 87360       87360  서울특별시 강남구 청담동    전세    80000  2019   오피스텔    45.09  17.0
#
# ...

# %%
df2 = pd.read_csv('경도위도값.csv')
df2.drop(columns = 'Unnamed: 0',  inplace = True)
df2
# Out:
#                      도로명주소   Latitude   Longitude
# 0          서울특별시 강남구 논현로4길  37.473722  127.052725
# 1         서울특별시 강남구 논현로10길  37.474587  127.049960
# 2         서울특별시 강남구 개포로20길  37.476862  127.048105
# 3         서울특별시 강남구 개포로15길  37.479661  127.045622
# 4          서울특별시 강남구 논현로6길  37.473422  127.051314
# ...                    ...        ...         ...
# 3724     서울특별시 강남구 역삼로 432  37.501439  127.054330
# 3725    서울특별시 강남구 압구정로 461  37.525283  127.047239
# 3726    서울특별시 강남구 도산대로 406  37.522821  127.039963
# 3727   서울특별시 강남구 논현로20길 12  37.478097  127.045854
# 3728  서울특별시 강남구 언주로 432-10  37.502156  127.044070
#
# [3729 rows x 3 columns]

# %%
df1 = df1.merge(df2, how='left', on='도로명주소')
df1.drop(columns = 'Unnamed: 0',  inplace = True)
df1
# Out:
#                  시군구 전월세구분  보증금(만원)  건축년도     구분  전용면적(㎡)     층  \
# 0      서울특별시 강남구 개포동    전세     7500  1989  단독다가구    44.00   3.0
# 1      서울특별시 강남구 개포동    전세    11000  1994  단독다가구    44.00   3.0
# 2      서울특별시 강남구 개포동    전세    16800  2000  단독다가구    44.00   3.0
# 3      서울특별시 강남구 개포동    전세    13000  1989  단독다가구    44.00   3.0
# 4      서울특별시 강남구 개포동    전세     8000  1995  단독다가구    44.00   3.0
# ...              ...   ...      ...   ...    ...      ...   ...
# 87356  서울특별시 강남구 청담동    전세    10000  2003   오피스텔    17.73   3.0
# 87357  서울특별시 강남구 청담동    전세    10500  2003   오피스텔    17.73   1.0
# 87358  서울특별시 강남구 청담동    전세    11000  2003   오피스텔    17.73   1.0
# 87359  서울특별시 강남구 청담동    전세    13000  1991   오피스텔    22.77  11.0
# 87360  서울특별시 강남구 청담동    전세    80000  2019   오피스텔    45.09  17.0
#
#                      도로명주소        계약시작        계약종료       계약년월일    구  건축나이  \
# 0          서울특별시 강남구 논현로4길  2022-06-01  2024-06-01  2022-06-01  강남구    34
# ...
