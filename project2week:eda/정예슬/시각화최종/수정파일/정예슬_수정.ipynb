# %% [markdown]
# # 👀 2-5-1.문화, 외식 인프라가 최근방 아파트 전세값에 영향을 미치는가?
# -서울열린데이터광장 > 서울시 강남구 대규모점포&휴게음식점 인허가 정보 데이터
#  -> 2018년~2022년까지의 데이터를 보기 위해, ['인허가일자'] < '230101'& ['폐업일자'] >= '20180101'로 필터링.
#  -> 위도,경도 추출을 위해 도로명주소(oo로)까지만 전처리.
#
# ![image.png](attachment:image.png)
#
# - 어디지역을 주의깊게 봐야하지?
# ![image-2.png](attachment:image-2.png)
# - 보기어렵네 folium 사용
#
# ![인프라+전세가 지도.png](attachment:인프라+전세가 지도.png)
# ![인프라+전세가 지도 범례.png](attachment:인프라+전세가 지도 범례.png)
#
# - 강남구 무슨 동인지? 어디동의 어떤 경향인지? 설명이 필요해
#   (-> 전세가 평균을 나타낸 히트맵 + 이미지에 동별 표시함)
#
# - 경향이 없는 것. 정말 많이 몰려있는 것이 핵심이긴 하지만 설명이 필요할 듯 문구로!
#   1. 스타벅스가 서울의 다른 구에 비해서도 엄청 많아서인지, 스타벅스를 중심으로 일대의 가격이 올라가지 않는다.
#   2. 스타벅스는 사업체수가 가장 많은 역삼동에 일렬로 들어선 흥미로운 모습을 보인다.
#   (사업체수 지도 이미지)
#   3. 맥도날드,미쉐린 레스토랑,백화점,전통시장도 주변 전세가에 영향을 주지 않는 것은 동일해 보였다.
#   4. 역삼동을 제외하고는 북쪽,남쪽에 학교(분홍마커)들이 많은데, 그렇다고 학교들이 전세가에 영향을 주는 것으론 보이지 않는다.
#
#  => 강남은 스세권,맥세권 등의 상권이 전세가에 영향을 주지 않는 특이한 동네인듯 하다. 그냥 강남은 강남이다.
#
#  (지도 이미지에는 일부러 위의 글은 안 적었어요. ppt에서 올릴게요.)

# %% [markdown]
# # 👀 정권교체시 전세가격에 영향을 미칠까?
# - 국토교통부 실거래가공개시스템 > 2011년 12월~22년 11월말까지의 아파트 전세가 데이터
#   -> 이명박정권 기간의 데이터 존재x, 따라서 박근혜정권부터 수집
#   -> 평상시와 비교를 위해, 18대 대선 1년전 데이터부터 수집
#   -> 윤석열 정권 교체 후 6개월동안의 경과 파악
#
#
#
# - 그래프를 보면 확 이해가 되긴하는데 설명을 텍스트로 담아주세요
# - 거시적인 경향이랑 중요하다고 생각하는 포인트 2~3개요
#
#  1. 당선 확정 및 새로운 정권이 시작되면 거래량 감소
#  2. 금리가 3%대로 처음 진입한 2022년도를 제외하고는, 매해 연말에는 거래량 증가
#  3. 가을에는 거래량이 최저 or 하락세
